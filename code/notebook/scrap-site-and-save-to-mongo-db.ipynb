# %% [markdown]
# # The following codes download the sitemap json and save it to files. Then scrap the website one by one

# %% [markdown]
# ## Model classes for the scrapper

# %%
class SiteData:
    def __init__(self):
        pass


class PageData:
    def __init__(self, url: str, content: str, text: str, images: list):
        self.url = url
        self.content = content
        self.text = text
        self.images = images

    def __str__(self):
        return self.url

    __repr__ = __str__

# %% [markdown]
# ## Save sitemap xml to json file

# %%
import json
import requests
from bs4 import BeautifulSoup, SoupStrainer
from datetime import datetime

content_strainer = SoupStrainer(id="content-main")
def save_site_map_json():
    print('Save site map started...')
    sitemap_index = requests.get("https://www.uni-bamberg.de/sitemap.xml")
    sitemap_strainer = SoupStrainer("sitemap")
    sitemap_link_strainer = SoupStrainer("url")
    sitemap_soup = BeautifulSoup(
        markup=sitemap_index.content, parse_only=sitemap_strainer, features="xml"
    )
    # Die einzelnen Sitemaps und deren letztes Änderungsdatum aus der globalen Sitemap auslesen und als Liste ausgeben
    sitemap_links = list(
        map(
            lambda n: {
                "link": n.loc.text,
                "lastmod": datetime.fromisoformat(n.lastmod.text),
            },
            sitemap_soup.contents,
        )
    )
    site_links = list()
    # Durch die einzelnen Sitemaps durchgehen
    for sitemap_link in sitemap_links:
        sitemap_content = BeautifulSoup(
            markup=requests.get(sitemap_link.get("link")).content,
            parse_only=sitemap_link_strainer,
            features="xml",
        )
        # Die Seiten aus der aktuellen Sitemap auslesen und mit dem Zeitpunkt der letzten Änderung ablegen
        site_links.extend(
            list(
                map(
                    lambda n: {
                        "link": n.loc.text,
                        "lastmod": datetime.fromisoformat(n.lastmod.text),
                    },
                    sitemap_content.contents,
                )
            )
        )
    # Die ausgelesenen Links als JSON abspeicher, damit man nicht jedes Mal die Sitemaps erneut abrufen muss (kann manchmal dauern, da die z.T. wohl erst bei Zugriff ereugt werden)
    f = open("sitemap.json", "w")
    json.dump(site_links, fp=f, default=str)
    f.close()
    print('Site map saved.')

# %% [markdown]
# ## Load site map from the json file

# %%
def load_site_map_json() -> list:
    print("Load site map started...")
    with open(file="sitemap.json", mode="r") as f:
        sitemaps = json.load(f)
    print("Site map loaded.")
    return sitemaps

# %% [markdown]
# ## Load a site from a given url

# %%
def load_site(url: str) -> PageData:
    print(f"Load site started for: {url.get('link')}")
    temp = requests.get(url.get("link")).content
    soup = BeautifulSoup(
        markup=temp,
        parse_only=content_strainer,
        features="lxml",
    )
    try:
        images = list(
            map(
                lambda n: {
                    "src": n.get("src"),
                    "title": n.get("title"),
                    "alt": n.get("alt"),
                },
                soup.findAll("img"),
            )
        )
    except:
        images = list()
    data = PageData(
        url["link"], str(soup.prettify()), soup.get_text(" ", strip=True), images
    )
    print("Site loaded.")
    return data

# %% [markdown]
# ## Main code to run the scrapper

# %%
import time
import pymongo
from multiprocessing import Pool

st = time.time()
pool = Pool()


site_map = load_site_map_json()
if len(site_map) == 0:
    save_site_map_json()
    site_map = load_site_map_json()

# Initiate mongo db

mongo_client = pymongo.MongoClient()

mongo_database = mongo_client["rag"]
mongo_pages = mongo_database["pages"]


timestamp = datetime.now().replace(microsecond=0).isoformat()

timestamp = datetime.now().replace(microsecond=0).isoformat()
for page in pool.imap(load_site, site_map, 100):
    print(page.url)
    mongo_pages.update_one(
        filter={"_id": page.url},
        update={
            "$set": {
                "_id": page.url,
                "last_update": timestamp,
                "content": page.content,
                "text": page.text,
                "images": page.images,
            }
        },
        upsert=True,
    )
    print(f"Content is : {page.content}")
end = time.time()
print((end - st))
pool.close()
# Out:
# Load site started for: https://www.uni-bamberg.de/abt-studium/aufgaben/pruefungs-studienordnungen/bachelorstudiengaenge
/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/bauforschung/forschung/projekte/bamberger-dom/die-mittelschiffsgewoelbe/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/kunstgesch1/lehrstuhlinhaber/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/germ-lingdaf/personen/ehemalige/prof-dr-helmut-glueck/helmutglueck-publikationen/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/slavistik/sprachpraxis/ukrainisch/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/sowi/kontaktnavigation/kontakt/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/bwl-finanz/lehrstuhl-team/lehrstuhlinhaber/
# Site loaded.Site loaded.
#
# Site loaded.Load site started for: https://www.uni-bamberg.de/turkologie/forschung/Load site started for: https://www.uni-bamberg.de/geo1/projekte-und-transfer/kooperationen/
#
#
# Load site started for: https://www.uni-bamberg.de/relpaed/studium/pruefungen/themen/lahs/95-91/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/pruefungsamt/studiengangsspezifische-infos-ansprechpartner/teilbereich-1/masterstudiengaenge/vawi/Site loaded.
#
# Load site started for: https://www.uni-bamberg.de/arabistik/studium/lehrveranstaltungen/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/kunstgesch1/lehrbeauftragte/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/orientalistik/studium/
# Site loaded.Site loaded.
#
# Load site started for: https://www.uni-bamberg.de/studienangebot/Load site started for: https://www.uni-bamberg.de/germanistik/
#
# Site loaded.Site loaded.
# Load site started for: https://www.uni-bamberg.de/geodidaktik/kontaktnavigation/kontakt/
# Load site started for: https://www.uni-bamberg.de/ub/kurse-tutorials/online-tutorials/
#
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/sowi/fs/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/slavistik/sprachpraxis/bulgarisch/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/musikpaed/kontaktnavigation/kontakt/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/hist-ng/forschung/projekte/arbeitsstelle-zur-geschichte-der-mehrsprachigkeit/prof-glueck-agdaf-projekt/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/pruefungsamt/studiengangsspezifische-infos-ansprechpartner/teilbereich-1/bachelorstudiengaenge/bachelorstudiengang-betriebswirtschaftslehre/
# Site loaded.Site loaded.
#
# Load site started for: https://www.uni-bamberg.de/histgeo/kontaktnavigation/kontakt/Load site started for: https://www.uni-bamberg.de/sowi/faecher-und-institute/Site loaded.Site loaded.
#
#
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/turkologie/transfer/Site loaded.
#
#
# Load site started for: https://www.uni-bamberg.de/bwl-finanz/lehrstuhl-team/sekretariat/Load site started for: https://www.uni-bamberg.de/kunstgesch1/sekretariat/
# Site loaded.Load site started for: https://www.uni-bamberg.de/fbe/forschung/abgeschlossen/bildarchiv-zur-geschichte-der-oeffentlichen-kleinkindererziehung/
#
#
# Load site started for: https://www.uni-bamberg.de/bwl-personal/news/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/abt-personal/personal3-1/aufgaben/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/orientalistik/forschung/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/relpaed/studium/pruefungen/themen/lahs/00-96/Site loaded.
#
# Load site started for: https://www.uni-bamberg.de/restaurierungswissenschaft/personen/mitarbeiterinnen/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/minf/studium/lv/aud-b/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/orientalistik/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/musikpaed/forschung/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/hist-ng/forschung/projekte/arbeitsstelle-zur-geschichte-der-mehrsprachigkeit/prof-glueck-agdaf-publika/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/pruefungsamt/kontaktnavigation/kontakt/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/ktheo/
# Site loaded.Site loaded.
#
# Load site started for: https://www.uni-bamberg.de/bwl-finanz/lehrstuhl-team/mitarbeiter/Load site started for: https://www.uni-bamberg.de/wima/
# Site loaded.Site loaded.
#
#
# Load site started for: https://www.uni-bamberg.de/abt-personal/personal3-2/aufgaben/Load site started for: https://www.uni-bamberg.de/turkologie/service/
# Site loaded.
#
# Load site started for: https://www.uni-bamberg.de/sportdidaktik/forschungsstelle-fuer-angewandte-sportwissenschaften-ffas/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/international-office/wo-und-wie-man-uns-findet/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/kunstgesch1/forschung/abschlussarbeiten/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/germ-didaktik/lehrstuhlteam/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/slavling/lehre/lehrveranstaltungen/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/orientalistik/transfer/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/romanistik/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/relpaed/studium/pruefungen/themen/lahs/90-86/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/germ-ling/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/hist-ng/forschung/projekte/arbeitsstelle-zur-geschichte-der-mehrsprachigkeit/prof-glueck-agdaf-publika/reihe-fremdsprachen-in-geschichte-und-gegenwart/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/pruefungsamt/studiengangsspezifische-infos-ansprechpartner/pruefungsamt-teilbereich2/diplomstudiengaenge/diplomstudiengang-katholische-theologie/
# Site loaded.
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/ktheo/kontaktnavigation/kontakt/Load site started for: https://www.uni-bamberg.de/huwi/personen-und-einrichtungen/fachbereichsrat/
# Site loaded.Site loaded.
#
#
# Load site started for: https://www.uni-bamberg.de/abt-personal/personal3-3/aufgaben/Load site started for: https://www.uni-bamberg.de/bwl-finanz/lehrstuhl-team/research-fellows/
#
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/blpsych/Site loaded.
#
# Site loaded.Load site started for: https://www.uni-bamberg.de/germ-ling/studium/
#
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/international-office/ihre-ansprechpersonen/Load site started for: https://www.uni-bamberg.de/pathopsych/
#
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/relpaed/studium/pruefungen/themen/lahsdid/herbst2010-fruehjahr2006/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/slavling/personal/prof-em-dr-sebastian-kempgen/service-und-transfer/fonts-fuer-slavisten/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/slavistik/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/abt-studium/aufgaben/pruefungs-studienordnungen/masterstudiengaenge/allgemeine-pruefungsordnung-fakultaeten-geistes-und-kulturwissenschaften-sowie-humanwissenschaften/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/orientalistik/kontakt/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/germ-ling/hinweise/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/sowi/pa/bwl-studiengaenge/
# Site loaded.
# Load site started for: https://www.uni-bamberg.de/hist-ng/forschung/projekte/arbeitsstelle-zur-geschichte-der-mehrsprachigkeit/prof-glueck-agdaf-publika/reihe-geschichte-des-deutschen-als-fremdsprache/
# Site loaded.Site loaded.
#
# Load site started for: https://www.uni-bamberg.de/auslandsstudium/ich